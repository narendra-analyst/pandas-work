# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\Narendra Work Files\Data Analyst\CSV Files\dirty_cafe_sales.csv")
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %% [markdown]
# # Check Data Quality

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  str
#  1   Item              9667 non-null   str
#  2   Quantity          9862 non-null   str
#  3   Price Per Unit    9821 non-null   str
#  4   Total Spent       9827 non-null   str
#  5   Payment Method    7421 non-null   str
#  6   Location          6735 non-null   str
#  7   Transaction Date  9841 non-null   str
# dtypes: str(8)
# memory usage: 625.1 KB

# %%
df.describe()
# Out:
#        Transaction ID   Item Quantity Price Per Unit Total Spent  \
# count           10000   9667     9862           9821        9827
# unique          10000     10        7              8          19
# top       TXN_1961373  Juice        5            3.0         6.0
# freq                1   1171     2013           2429         979
#
#         Payment Method  Location Transaction Date
# count             7421      6735             9841
# unique               5         4              367
# top     Digital Wallet  Takeaway          UNKNOWN
# freq              2291      3022              159

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %% [markdown]
# # Clean the Data

# %%
df.replace("UNKNOWN", np.nan, inplace=True)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %% [markdown]
# Fill Missing Values

# %% [markdown]
# Item

# %%
df.fillna({"Item": df["Item"].mode()[0]}, inplace=True)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401     Juice        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %% [markdown]
# Quantity

# %%
df["Quantity"] = pd.to_numeric(df["Quantity"], errors="coerce")
df["Quantity"] = df["Quantity"].fillna(df["Quantity"].median())

# %% [markdown]
# Price Per Unit

# %%
df["Price Per Unit"] = pd.to_numeric(df["Price Per Unit"], errors="coerce")
df["Price Per Unit"] = df["Price Per Unit"].fillna(df["Price Per Unit"].median())

# %% [markdown]
# Total Spent

# %%
df["Total Spent"] = pd.to_numeric(df["Total Spent"], errors="coerce")
df["Total Spent"] = df["Total Spent"].fillna(df["Quantity"] * df["Price Per Unit"])

# %% [markdown]
# Payment Method

# %%
df["Payment MEthod"] = df["Payment Method"].fillna(df["Payment Method"].mode()[0])

# %% [markdown]
# Location

# %%
df["Location"] = df["Location"].fillna(df["Location"].mode()[0])

# %% [markdown]
# Transaction Date

# %%
df["Transaction Date"] = pd.to_datetime(df["Transaction Date"],errors="coerce")
df["Transaction Date"] = df["Transaction Date"].fillna(df["Transaction Date"].mode()[0])

# %% [markdown]
# # Verify Cleaning

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity               0
# Price Per Unit         0
# Total Spent            0
# Payment Method      2579
# Location               0
# Transaction Date       0
# Payment MEthod         0
# dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Transaction ID',
#  'Item',
#  'Quantity',
#  'Price Per Unit',
#  'Total Spent',
#  'Payment Method',
#  'Location',
#  'Transaction Date',
#  'Payment MEthod']

# %%
Fix the duplicate column

# %%
df["Payment Method"] = df["Payment Method"].fillna(df["Payment MEthod"])
df.drop("Payment MEthod", axis=1, inplace=True)

# %% [markdown]
# Fill remaining missing values

# %%
df["Item"] = df["Item"].fillna(df["Item"].mode()[0])
df["Payment Method"] = df["Payment Method"].fillna(df["Payment Method"].mode()[0])

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %% [markdown]
# # Create a Revenue Column Check

# %% [markdown]
# Sometimes Total Spent may still contain incorrect values. Verify:

# %%
df["Calculated Total"] = df["Quantity"] * df["Price Per Unit"]
df[["Quantity","Price Per Unit","Total Spent","Calculated Total"]].head()
# Out:
#    Quantity  Price Per Unit  Total Spent  Calculated Total
# 0       2.0             2.0          4.0               4.0
# 1       4.0             3.0         12.0              12.0
# 2       4.0             1.0          4.0               4.0
# 3       2.0             5.0         10.0              10.0
# 4       2.0             2.0          4.0               4.0

# %% [markdown]
# # Chart

# %% [markdown]
# # 1.Top Selling Items

# %%
item_qty = df.groupby("Item")["Quantity"].sum().sort_values(ascending=False)

item_qty.plot(kind="bar", figsize=(8,5))
plt.title("Top Selling Items")
plt.ylabel("Quantity Sold")
plt.show()

# %% [markdown]
# # 2.Revenue by Item

# %%
revenue = df.groupby("Item")["Total Spent"].sum().sort_values(ascending=False)

revenue.plot(kind="bar", figsize=(8,5))
plt.title("Revenue by Item")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# # 3.Payment Method Usage

# %%
df["Payment Method"].value_counts().plot(kind="pie",autopct="%1.1f%%",figsize=(6,6))
plt.title("Payment Method Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# # 4.Revenue by Location

# %%
location_rev = df.groupby("Location")["Total Spent"].sum()

location_rev.plot(kind="bar", figsize=(6,4))
plt.title("Revenue by Location")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# # 5.Monthly Sales Trend

# %%
df["Month"] = df["Transaction Date"].dt.to_period("M")
monthly_sales = df.groupby("Month")["Total Spent"].sum()
monthly_sales.plot(marker="o", figsize=(10,5))
plt.title("Monthly Revenue Trend")
plt.ylabel("Revenue")
plt.grid(True)
plt.show()

# %% [markdown]
# # Useful Insights

# %% [markdown]
# Best-selling item

# %%
df.groupby("Item")["Quantity"].sum().sort_values(ascending=False).head()
# Out:
# Item
# Juice       4530.0
# Coffee      3551.0
# Salad       3469.0
# Cake        3467.0
# Sandwich    3428.0
# Name: Quantity, dtype: float64

# %% [markdown]
# Highest revenue item

# %%
df.groupby("Item")["Total Spent"].sum().sort_values(ascending=False).head()
# Out:
# Item
# Salad       17365.0
# Sandwich    13751.0
# Juice       13544.0
# Smoothie    13362.0
# Cake        10413.0
# Name: Total Spent, dtype: float64

# %% [markdown]
# Average order value

# %%
"Average Order Value:", round(df["Total Spent"].mean(),2)
# Out:
# ('Average Order Value:', np.float64(8.93))

# %% [markdown]
# Most used payment method

# %%
df["Payment Method"].value_counts()
# Out:
# Payment Method
# Digital Wallet    4870
# Credit Card       2273
# Cash              2258
# ERROR              306
# UNKNOWN            293
# Name: count, dtype: int64

# %% [markdown]
# Revenue by location

# %%
df.groupby("Location")["Total Spent"].sum()
# Out:
# Location
# ERROR        3252.5
# In-store    27260.5
# Takeaway    56000.5
# UNKNOWN      2794.0
# Name: Total Spent, dtype: float64
